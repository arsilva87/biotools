# %%
install.packages(c("shiny", "devtools"))
library(shiny)
library(devtools)

source_url("https://raw.githubusercontent.com/arsilva87/soilphysics/master/R/LLWR_App.R")
# Out:
# Installing packages into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘ini’, ‘desc’, ‘rprojroot’, ‘withr’, ‘xopen’, ‘clisymbols’, ‘gh’, ‘git2r’, ‘pkgbuild’, ‘pkgload’, ‘rcmdcheck’, ‘remotes’, ‘sessioninfo’, ‘usethis’
#
#
# SHA-1 hash of file is 390fe8a0dcc1a7b800797eed0b15a8248f5aa9a4
# function ()
# {
#     shinyApp(ui_LLWR, server_LLWR)
# }

# %%
LLWR_App()
# Out:
# Listening on http://127.0.0.1:3511
